# %%
#Apply Exploratory Data Analysis on the FifaDataset
#Convert the appropriate columns to machine understandable columns using label encoding
#Handle Null values
#Apply the correlation and remove the column which are more than 60% correlated 
#Apply the variance and remove the columns whose variance is less than 20%
#Understand the Dataset whether the dataset is corr

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fifa = pd.read_csv('D:/Assignment/Machine Learning/Project/fifa_cleaned.csv')

# %%
fifa
# Out:
#            id            name                         full_name  birth_date  \
# 0      158023        L. Messi    Lionel Andrés Messi Cuccittini  1987-06-24
# 1      190460      C. Eriksen      Christian  Dannemann Eriksen  1992-02-14
# 2      195864        P. Pogba                        Paul Pogba  1993-03-15
# 3      198219      L. Insigne                   Lorenzo Insigne  1991-06-04
# 4      201024    K. Koulibaly                 Kalidou Koulibaly  1991-06-20
# ...       ...             ...                               ...         ...
# 17949  204322     R. McKenzie                    Rory  McKenzie  1993-10-07
# 17950  239762       M. Sipľak                     Michal Sipľak  1996-02-02
# 17951  235155      J. Bekkema                       Jan Bekkema  1996-04-09
# 17952  244883      A. Al Yami               Abdulrahman Al Yami  1997-06-19
# 17953  247187  Júnior Brumado  José Francisco dos Santos Júnior  1999-05-15
#
# ...

# %%
# Applying Exploratory Data Analysis(EDA) on the FifaDataset

fifa.drop(['name','full_name','positions','nationality'],axis=1,inplace = True)

# %%
fifa
# Out:
#            id  birth_date  age  height_cm  weight_kgs  overall_rating  \
# 0      158023  1987-06-24   31     170.18        72.1              94
# 1      190460  1992-02-14   27     154.94        76.2              88
# 2      195864  1993-03-15   25     190.50        83.9              88
# 3      198219  1991-06-04   27     162.56        59.0              88
# 4      201024  1991-06-20   27     187.96        88.9              88
# ...       ...         ...  ...        ...         ...             ...
# 17949  204322  1993-10-07   25     175.26        74.8              67
# 17950  239762  1996-02-02   23     182.88        79.8              59
# 17951  235155  1996-04-09   22     185.42        89.8              59
# 17952  244883  1997-06-19   21     175.26        64.9              59
# 17953  247187  1999-05-15   19     190.50        79.8              59
#
#        potential   value_euro  wage_euro preferred_foot  ...   LWB   LDM  \
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 88 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             17954 non-null  int64
#  1   birth_date                     17954 non-null  object
#  2   age                            17954 non-null  int64
#  3   height_cm                      17954 non-null  float64
#  4   weight_kgs                     17954 non-null  float64
#  5   overall_rating                 17954 non-null  int64
#  6   potential                      17954 non-null  int64
#  7   value_euro                     17699 non-null  float64
#  8   wage_euro                      17708 non-null  float64
#  9   preferred_foot                 17954 non-null  object
#  10  international_reputation(1-5)  17954 non-null  int64
#  11  weak_foot(1-5)                 17954 non-null  int64
# ...

# %%
fifa.describe()
# Out:
#                   id           age     height_cm    weight_kgs  \
# count   17954.000000  17954.000000  17954.000000  17954.000000
# mean   215411.087780     25.565445    174.946921     75.301047
# std     29758.387106      4.705708     14.029449      7.083684
# min        16.000000     17.000000    152.400000     49.900000
# 25%    201117.250000     22.000000    154.940000     69.900000
# 50%    222919.000000     25.000000    175.260000     74.800000
# 75%    237613.500000     29.000000    185.420000     79.800000
# max    247607.000000     46.000000    205.740000    110.200000
#
#        overall_rating     potential    value_euro      wage_euro  \
# count    17954.000000  17954.000000  1.769900e+04   17708.000000
# mean        66.240169     71.430935  2.479280e+06    9902.134628
# std          6.963730      6.131339  5.687014e+06   21995.593750
# min         47.000000     48.000000  1.000000e+04    1000.000000
# 25%         62.000000     67.000000  3.250000e+05    1000.000000
# ...

# %%
# Handling Null values
fifa.isnull().sum()
# Out:
# id               0
# birth_date       0
# age              0
# height_cm        0
# weight_kgs       0
#               ...
# LB            2065
# LCB           2065
# CB            2065
# RCB           2065
# RB            2065
# Length: 88, dtype: int64

# %%
fifa.replace(np.nan,'0',inplace = True)

# %%
fifa.isnull().sum()
# Out:
# id            0
# birth_date    0
# age           0
# height_cm     0
# weight_kgs    0
#              ..
# LB            0
# LCB           0
# CB            0
# RCB           0
# RB            0
# Length: 88, dtype: int64

# %%
fifa.describe()
# Out:
#                   id           age     height_cm    weight_kgs  \
# count   17954.000000  17954.000000  17954.000000  17954.000000
# mean   215411.087780     25.565445    174.946921     75.301047
# std     29758.387106      4.705708     14.029449      7.083684
# min        16.000000     17.000000    152.400000     49.900000
# 25%    201117.250000     22.000000    154.940000     69.900000
# 50%    222919.000000     25.000000    175.260000     74.800000
# 75%    237613.500000     29.000000    185.420000     79.800000
# max    247607.000000     46.000000    205.740000    110.200000
#
#        overall_rating     potential  international_reputation(1-5)  \
# count    17954.000000  17954.000000                   17954.000000
# mean        66.240169     71.430935                       1.111674
# std          6.963730      6.131339                       0.392168
# min         47.000000     48.000000                       1.000000
# ...

# %%
# setting up Label Encoding

from sklearn.preprocessing import LabelEncoder
foot = LabelEncoder()
fifa["preferred_foot"]=foot.fit_transform(fifa["preferred_foot"])

# %%
fifa
# Out:
#            id  birth_date  age  height_cm  weight_kgs  overall_rating  \
# 0      158023  1987-06-24   31     170.18        72.1              94
# 1      190460  1992-02-14   27     154.94        76.2              88
# 2      195864  1993-03-15   25     190.50        83.9              88
# 3      198219  1991-06-04   27     162.56        59.0              88
# 4      201024  1991-06-20   27     187.96        88.9              88
# ...       ...         ...  ...        ...         ...             ...
# 17949  204322  1993-10-07   25     175.26        74.8              67
# 17950  239762  1996-02-02   23     182.88        79.8              59
# 17951  235155  1996-04-09   22     185.42        89.8              59
# 17952  244883  1997-06-19   21     175.26        64.9              59
# 17953  247187  1999-05-15   19     190.50        79.8              59
#
#        potential   value_euro wage_euro  preferred_foot  ...   LWB   LDM  \
# ...

# %%
fifa[fifa['preferred_foot']==1].head()
# Out:
#        id  age  height_cm  weight_kgs  overall_rating  potential  value_euro  \
# 1  190460   27     154.94        76.2              88         89  69500000.0
# 2  195864   25     190.50        83.9              88         91  73000000.0
# 3  198219   27     162.56        59.0              88         88  62000000.0
# 4  201024   27     187.96        88.9              88         91  60000000.0
# 5  203376   27     193.04        92.1              88         90  59500000.0
#
#   wage_euro  preferred_foot  international_reputation(1-5)  ...  penalties  \
# 1  205000.0               1                              3  ...         67
# 2  255000.0               1                              4  ...         82
# 3  165000.0               1                              3  ...         61
# 4  135000.0               1                              3  ...         33
# 5  215000.0               1                              3  ...         62
#
# ...

# %%
X=fifa.drop("potential",axis=1) # independent variable

# %%
y=fifa["potential"] # dependent variable

# %%
X.head()
# Out:
#        id  birth_date  age  height_cm  weight_kgs  overall_rating  \
# 0  158023  1987-06-24   31     170.18        72.1              94
# 1  190460  1992-02-14   27     154.94        76.2              88
# 2  195864  1993-03-15   25     190.50        83.9              88
# 3  198219  1991-06-04   27     162.56        59.0              88
# 4  201024  1991-06-20   27     187.96        88.9              88
#
#     value_euro wage_euro  preferred_foot  international_reputation(1-5)  ...  \
# 0  110500000.0  565000.0               0                              5  ...
# 1   69500000.0  205000.0               1                              3  ...
# 2   73000000.0  255000.0               1                              4  ...
# 3   62000000.0  165000.0               1                              3  ...
# 4   60000000.0  135000.0               1                              3  ...
#
#     LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB
# ...

# %%
y.head()
# Out:
# 0    94
# 1    89
# 2    91
# 3    88
# 4    91
# Name: potential, dtype: int64

# %%
# correlation plot of EDA
fifa.corr()
# Out:
#                                      id       age  height_cm  weight_kgs  \
# id                             1.000000 -0.745789  -0.060664   -0.193974
# age                           -0.745789  1.000000   0.059579    0.233819
# height_cm                     -0.060664  0.059579   1.000000    0.495320
# weight_kgs                    -0.193974  0.233819   0.495320    1.000000
# overall_rating                -0.421439  0.461529   0.038080    0.150521
# potential                      0.057837 -0.259579   0.008526   -0.015099
# preferred_foot                 0.001406  0.002259   0.050176    0.072883
# international_reputation(1-5) -0.362582  0.259977   0.026850    0.085086
# weak_foot(1-5)                -0.075384  0.061108  -0.130464   -0.128875
# skill_moves(1-5)              -0.056325  0.029681  -0.320141   -0.353601
# crossing                      -0.132995  0.133357  -0.388805   -0.394145
# finishing                     -0.086259  0.074761  -0.296794   -0.294710
# ...

# %%
# Separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=40)
X_train.shape,y_train.shape
# Out:
# ((12567, 87), (12567,))

# %%
# Applying Correlation

X_train.corr() # correlation between columns
# Out:
#                                      id       age  height_cm  weight_kgs  \
# id                             1.000000 -0.745839  -0.063193   -0.195370
# age                           -0.745839  1.000000   0.061984    0.234629
# height_cm                     -0.063193  0.061984   1.000000    0.493077
# weight_kgs                    -0.195370  0.234629   0.493077    1.000000
# overall_rating                -0.409502  0.451586   0.037548    0.143779
# preferred_foot                 0.001917  0.004183   0.048633    0.073870
# international_reputation(1-5) -0.358579  0.254819   0.033882    0.089571
# weak_foot(1-5)                -0.068438  0.057518  -0.135470   -0.134341
# skill_moves(1-5)              -0.047484  0.022910  -0.320622   -0.355238
# crossing                      -0.121222  0.123532  -0.383799   -0.392556
# finishing                     -0.074594  0.064923  -0.298483   -0.294068
# heading_accuracy              -0.100295  0.142302  -0.043799    0.026422
# ...

# %%
import seaborn as sns
# Using Pearson Correlation
cor=X_train.corr()
fig,ax=plt.subplots()
fig.set_size_inches(80,20)
sns.heatmap(cor,annot=True)
plt.show()

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(X_train,0.6) # remove the column which are more than 60% correlated 
len(set(corr_features))
# Out:
# 33

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_train # removing columns correlation>60% (33 columns)
# Out:
# C:\Users\srira\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#            id  birth_date  height_cm  weight_kgs  overall_rating value_euro  \
# 7196   245393  1998-07-06     154.94        68.0              60   325000.0
# 15447  201041  1991-04-12     182.88        78.0              72  2900000.0
# 15448  224336  1991-11-14     185.42        73.0              72  3000000.0
# 3300   174665  1986-10-06     187.96        82.1              63   250000.0
# 8718   158667  1985-01-22     187.96        86.2              63   220000.0
# ...       ...         ...        ...         ...             ...        ...
# 11532  240922  1998-03-24     182.88        74.8              66  1100000.0
# ...

# %%
fifa.drop(['work_rate','body_type','club_team','club_position','club_join_date','national_team','national_team_position','tags','traits'],axis=1,inplace = True)

# %%
fifa.drop('contract_end_year',axis=1,inplace=True)

# %%
fifa.drop(['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB'] ,axis=1,inplace=True)

# %%
# Applying Variance
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0.2) # remove the columns whose variance is less than 20%
var_thres.fit(fifa)
# Out:
# VarianceThreshold(threshold=0.2)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
columns_having_more_than_20=fifa.columns[var_thres.get_support()==True]
len(columns_having_more_than_20)
# Out:
# 49

# %%
len(fifa.columns)
# Out:
# 51

# %%
columns_having_less_than_20=fifa.columns[var_thres.get_support()==False]
len(columns_having_less_than_20)
# Out:
# 2
